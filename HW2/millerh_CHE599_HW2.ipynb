# %% [markdown]
# # CHE 599: homework 2

# %%
using CSV # for reading in CSV files as DataFrames
using DataFrames
using PyPlot # for plotting

# %%
# (optional) change the style. see styles here: https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html
PyPlot.matplotlib.style.use("bmh")                                    
                                                                                  
# (optional) change settings for all plots at once, e.g. I like larger font size                           
rcParams = PyPlot.PyDict(PyPlot.matplotlib.rcParams)                           
rcParams["font.size"] = 16

# (optional) change the max width of columns of `DataFrame`
#  that are displayed in the Juptyer Notebook.
ENV["COLUMNS"] = 300 # characters
# Out:
# 300

# %% [markdown]
# # automobiles
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/f0/Ford_Pinto.jpg" width=250>
#
# (1) read in the CSV file `automobiles.csv` ([source of data](https://archive.ics.uci.edu/ml/datasets/automobile)). the names of the columns are not in the `.csv` file but are described [here](http://mlr.cs.umass.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.names). for your convenience, I made an array of the column names below.

# %%
col_names = [:mpg, :cylinders, :displacement, :horsepower, :weight, :acceleration, :model_year, :origin, :car_name]
# Out:
# 9-element Array{Symbol,1}:
#  :mpg
#  :cylinders
#  :displacement
#  :horsepower
#  :weight
#  :acceleration
#  :model_year
#  :origin
#  :car_name

# %%
df_auto = CSV.read("automobiles.csv", header = col_names, copycols = true)
# Out:
# 398×9 DataFrame
# │ Row │ mpg     │ cylinders │ displacement │ horsepower │ weight  │ acceleration │ model_year │ origin │ car_name                          │
# │     │ Float64 │ Int64     │ Float64      │ Float64⍰   │ Float64 │ Float64      │ Int64      │ Int64  │ String                            │
# ├─────┼─────────┼───────────┼──────────────┼────────────┼─────────┼──────────────┼────────────┼────────┼───────────────────────────────────┤
# │ 1   │ 18.0    │ 8         │ 307.0        │ 130.0      │ 3504.0  │ 12.0         │ 70         │ 1      │ chevrolet,chevelle,malibu         │
# │ 2   │ 15.0    │ 8         │ 350.0        │ 165.0      │ 3693.0  │ 11.5         │ 70         │ 1      │ buick,skylark,320                 │
# │ 3   │ 18.0    │ 8         │ 318.0        │ 150.0      │ 3436.0  │ 11.0         │ 70         │ 1      │ plymouth,satellite                │
# │ 4   │ 16.0    │ 8         │ 304.0        │ 150.0      │ 3433.0  │ 12.0         │ 70         │ 1      │ amc,rebel,sst                     │
# │ 5   │ 17.0    │ 8         │ 302.0        │ 140.0      │ 3449.0  │ 10.5         │ 70         │ 1      │ ford,torino                       │
# │ 6   │ 15.0    │ 8         │ 429.0        │ 198.0      │ 4341.0  │ 10.0         │ 70         │ 1      │ ford,galaxie,500                  │
# │ 7   │ 14.0    │ 8         │ 454.0        │ 220.0      │ 4354.0  │ 9.0          │ 70         │ 1      │ chevrolet,impala                  │
# │ 8   │ 14.0    │ 8         │ 440.0        │ 215.0      │ 4312.0  │ 8.5          │ 70         │ 1      │ plymouth,fury,iii                 │
# │ 9   │ 14.0    │ 8         │ 455.0        │ 225.0      │ 4425.0  │ 10.0         │ 70         │ 1      │ pontiac,catalina                  │
# │ 10  │ 15.0    │ 8         │ 390.0        │ 190.0      │ 3850.0  │ 8.5          │ 70         │ 1      │ amc,ambassador,dpl                │
# ⋮
# │ 388 │ 38.0    │ 6         │ 262.0        │ 85.0       │ 3015.0  │ 17.0         │ 82         │ 1      │ oldsmobile,cutlass,ciera,(diesel) │
# │ 389 │ 26.0    │ 4         │ 156.0        │ 92.0       │ 2585.0  │ 14.5         │ 82         │ 1      │ chrysler,lebaron,medallion        │
# │ 390 │ 22.0    │ 6         │ 232.0        │ 112.0      │ 2835.0  │ 14.7         │ 82         │ 1      │ ford,granada,l                    │
# │ 391 │ 32.0    │ 4         │ 144.0        │ 96.0       │ 2665.0  │ 13.9         │ 82         │ 3      │ toyota,celica,gt                  │
# │ 392 │ 36.0    │ 4         │ 135.0        │ 84.0       │ 2370.0  │ 13.0         │ 82         │ 1      │ dodge,charger,2.2                 │
# │ 393 │ 27.0    │ 4         │ 151.0        │ 90.0       │ 2950.0  │ 17.3         │ 82         │ 1      │ chevrolet,camaro                  │
# │ 394 │ 27.0    │ 4         │ 140.0        │ 86.0       │ 2790.0  │ 15.6         │ 82         │ 1      │ ford,mustang,gl                   │
# │ 395 │ 44.0    │ 4         │ 97.0         │ 52.0       │ 2130.0  │ 24.6         │ 82         │ 2      │ vw,pickup                         │
# │ 396 │ 32.0    │ 4         │ 135.0        │ 84.0       │ 2295.0  │ 11.6         │ 82         │ 1      │ dodge,rampage                     │
# │ 397 │ 28.0    │ 4         │ 120.0        │ 79.0       │ 2625.0  │ 18.6         │ 82         │ 1      │ ford,ranger                       │
# │ 398 │ 31.0    │ 4         │ 119.0        │ 82.0       │ 2720.0  │ 19.4         │ 82         │ 1      │ chevy,s-10                        │

# %% [markdown]
# (2) how many automobiles are there in the data set?

# %%
num_auto = (size(df_auto))[1]
# Out:
# 398

# %% [markdown]
# (3) the `:horsepower` column has a `?` associated with it in the display, indicating that it has `missing `values. how many automobiles are missing information about their horsepower?

# %%
num_missing = sum([ismissing(horse) for horse in df_auto[:, :horsepower]])
# Out:
# 6

# %% [markdown]
# (4) drop the rows from the `DataFrame` that contain a `missing` attribute

# %%
dropmissing!(df_auto)
# Out:
# 392×9 DataFrame
# │ Row │ mpg     │ cylinders │ displacement │ horsepower │ weight  │ acceleration │ model_year │ origin │ car_name                          │
# │     │ Float64 │ Int64     │ Float64      │ Float64    │ Float64 │ Float64      │ Int64      │ Int64  │ String                            │
# ├─────┼─────────┼───────────┼──────────────┼────────────┼─────────┼──────────────┼────────────┼────────┼───────────────────────────────────┤
# │ 1   │ 18.0    │ 8         │ 307.0        │ 130.0      │ 3504.0  │ 12.0         │ 70         │ 1      │ chevrolet,chevelle,malibu         │
# │ 2   │ 15.0    │ 8         │ 350.0        │ 165.0      │ 3693.0  │ 11.5         │ 70         │ 1      │ buick,skylark,320                 │
# │ 3   │ 18.0    │ 8         │ 318.0        │ 150.0      │ 3436.0  │ 11.0         │ 70         │ 1      │ plymouth,satellite                │
# │ 4   │ 16.0    │ 8         │ 304.0        │ 150.0      │ 3433.0  │ 12.0         │ 70         │ 1      │ amc,rebel,sst                     │
# │ 5   │ 17.0    │ 8         │ 302.0        │ 140.0      │ 3449.0  │ 10.5         │ 70         │ 1      │ ford,torino                       │
# │ 6   │ 15.0    │ 8         │ 429.0        │ 198.0      │ 4341.0  │ 10.0         │ 70         │ 1      │ ford,galaxie,500                  │
# │ 7   │ 14.0    │ 8         │ 454.0        │ 220.0      │ 4354.0  │ 9.0          │ 70         │ 1      │ chevrolet,impala                  │
# │ 8   │ 14.0    │ 8         │ 440.0        │ 215.0      │ 4312.0  │ 8.5          │ 70         │ 1      │ plymouth,fury,iii                 │
# │ 9   │ 14.0    │ 8         │ 455.0        │ 225.0      │ 4425.0  │ 10.0         │ 70         │ 1      │ pontiac,catalina                  │
# │ 10  │ 15.0    │ 8         │ 390.0        │ 190.0      │ 3850.0  │ 8.5          │ 70         │ 1      │ amc,ambassador,dpl                │
# ⋮
# │ 382 │ 38.0    │ 6         │ 262.0        │ 85.0       │ 3015.0  │ 17.0         │ 82         │ 1      │ oldsmobile,cutlass,ciera,(diesel) │
# │ 383 │ 26.0    │ 4         │ 156.0        │ 92.0       │ 2585.0  │ 14.5         │ 82         │ 1      │ chrysler,lebaron,medallion        │
# │ 384 │ 22.0    │ 6         │ 232.0        │ 112.0      │ 2835.0  │ 14.7         │ 82         │ 1      │ ford,granada,l                    │
# │ 385 │ 32.0    │ 4         │ 144.0        │ 96.0       │ 2665.0  │ 13.9         │ 82         │ 3      │ toyota,celica,gt                  │
# │ 386 │ 36.0    │ 4         │ 135.0        │ 84.0       │ 2370.0  │ 13.0         │ 82         │ 1      │ dodge,charger,2.2                 │
# │ 387 │ 27.0    │ 4         │ 151.0        │ 90.0       │ 2950.0  │ 17.3         │ 82         │ 1      │ chevrolet,camaro                  │
# │ 388 │ 27.0    │ 4         │ 140.0        │ 86.0       │ 2790.0  │ 15.6         │ 82         │ 1      │ ford,mustang,gl                   │
# │ 389 │ 44.0    │ 4         │ 97.0         │ 52.0       │ 2130.0  │ 24.6         │ 82         │ 2      │ vw,pickup                         │
# │ 390 │ 32.0    │ 4         │ 135.0        │ 84.0       │ 2295.0  │ 11.6         │ 82         │ 1      │ dodge,rampage                     │
# │ 391 │ 28.0    │ 4         │ 120.0        │ 79.0       │ 2625.0  │ 18.6         │ 82         │ 1      │ ford,ranger                       │
# │ 392 │ 31.0    │ 4         │ 119.0        │ 82.0       │ 2720.0  │ 19.4         │ 82         │ 1      │ chevy,s-10                        │

# %% [markdown]
# (5) make a scatter plot of the data such that:
#
# * each point represents an automobile
# * x-axis is horsepower
# * y-axis is mpg (miles per gallon)
# * color of point is used to illustrate acceleration
# * a colorbar shows how the scale is depicted
# * the colorbar, x-axis, and y-axis are labeled.

# %%
#import Pkg 
#Pkg.add("StatsPlots")

# %%
figure()

xlabel("horsepower")
ylabel("mpg")
title("horsepower vs mpg")
scatter_auto = scatter(df_auto[:, :horsepower], df_auto[:, :mpg], c=df_auto[:, :acceleration], cmap=:viridis ) 
color = plt.colorbar(scatter_auto)    
color.ax.set_ylabel("acceleration", rotation=90)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject Text(521.4133333333335, 0.5, 'acceleration')

# %% [markdown]
# (6) remove from the `DataFrame` all automobiles that are not Fords. All Ford automobiles contain the string "ford" in the `:car_name` column. the function `occursin` will be useful here.
#
# ```julia
# occursin("ford", "i love ford pintos") # true
# occursin("ford", "i love subarus") # false
# ```

# %%
df_ford = filter(row -> occursin("ford", row[:car_name]) == true, df_auto)
# Out:
# 48×9 DataFrame
# │ Row │ mpg     │ cylinders │ displacement │ horsepower │ weight  │ acceleration │ model_year │ origin │ car_name                 │
# │     │ Float64 │ Int64     │ Float64      │ Float64    │ Float64 │ Float64      │ Int64      │ Int64  │ String                   │
# ├─────┼─────────┼───────────┼──────────────┼────────────┼─────────┼──────────────┼────────────┼────────┼──────────────────────────┤
# │ 1   │ 17.0    │ 8         │ 302.0        │ 140.0      │ 3449.0  │ 10.5         │ 70         │ 1      │ ford,torino              │
# │ 2   │ 15.0    │ 8         │ 429.0        │ 198.0      │ 4341.0  │ 10.0         │ 70         │ 1      │ ford,galaxie,500         │
# │ 3   │ 21.0    │ 6         │ 200.0        │ 85.0       │ 2587.0  │ 16.0         │ 70         │ 1      │ ford,maverick            │
# │ 4   │ 10.0    │ 8         │ 360.0        │ 215.0      │ 4615.0  │ 14.0         │ 70         │ 1      │ ford,f250                │
# │ 5   │ 19.0    │ 6         │ 250.0        │ 88.0       │ 3302.0  │ 15.5         │ 71         │ 1      │ ford,torino,500          │
# │ 6   │ 14.0    │ 8         │ 351.0        │ 153.0      │ 4154.0  │ 13.5         │ 71         │ 1      │ ford,galaxie,500         │
# │ 7   │ 13.0    │ 8         │ 400.0        │ 170.0      │ 4746.0  │ 12.0         │ 71         │ 1      │ ford,country,squire,(sw) │
# │ 8   │ 18.0    │ 6         │ 250.0        │ 88.0       │ 3139.0  │ 14.5         │ 71         │ 1      │ ford,mustang             │
# │ 9   │ 21.0    │ 4         │ 122.0        │ 86.0       │ 2226.0  │ 16.5         │ 72         │ 1      │ ford,pinto,runabout      │
# │ 10  │ 14.0    │ 8         │ 351.0        │ 153.0      │ 4129.0  │ 13.0         │ 72         │ 1      │ ford,galaxie,500         │
# ⋮
# │ 38  │ 22.3    │ 4         │ 140.0        │ 88.0       │ 2890.0  │ 17.3         │ 79         │ 1      │ ford,fairmont,4          │
# │ 39  │ 17.6    │ 8         │ 302.0        │ 129.0      │ 3725.0  │ 13.4         │ 79         │ 1      │ ford,ltd,landau          │
# │ 40  │ 15.5    │ 8         │ 351.0        │ 142.0      │ 4054.0  │ 14.3         │ 79         │ 1      │ ford,country,squire,(sw) │
# │ 41  │ 26.4    │ 4         │ 140.0        │ 88.0       │ 2870.0  │ 18.1         │ 80         │ 1      │ ford,fairmont            │
# │ 42  │ 34.4    │ 4         │ 98.0         │ 65.0       │ 2045.0  │ 16.2         │ 81         │ 1      │ ford,escort,4w           │
# │ 43  │ 29.9    │ 4         │ 98.0         │ 65.0       │ 2380.0  │ 20.7         │ 81         │ 1      │ ford,escort,2h           │
# │ 44  │ 20.2    │ 6         │ 200.0        │ 88.0       │ 3060.0  │ 17.1         │ 81         │ 1      │ ford,granada,gl          │
# │ 45  │ 24.0    │ 4         │ 140.0        │ 92.0       │ 2865.0  │ 16.4         │ 82         │ 1      │ ford,fairmont,futura     │
# │ 46  │ 22.0    │ 6         │ 232.0        │ 112.0      │ 2835.0  │ 14.7         │ 82         │ 1      │ ford,granada,l           │
# │ 47  │ 27.0    │ 4         │ 140.0        │ 86.0       │ 2790.0  │ 15.6         │ 82         │ 1      │ ford,mustang,gl          │
# │ 48  │ 28.0    │ 4         │ 120.0        │ 79.0       │ 2625.0  │ 18.6         │ 82         │ 1      │ ford,ranger              │

# %% [markdown]
# (7) of the Ford automobiles, how many unique numbers of cylinders are there?

# %%
num_cyl = unique(df_ford[:, :cylinders])
# Out:
# 3-element Array{Int64,1}:
#  8
#  6
#  4

# %%
groupby(df_ford, :cylinders)
# Out:
# GroupedDataFrame with 3 groups based on key: cylinders
# First Group (20 rows): cylinders = 8
# │ Row │ mpg     │ cylinders │ displacement │ horsepower │ weight  │ acceleration │ model_year │ origin │ car_name                 │
# │     │ Float64 │ Int64     │ Float64      │ Float64    │ Float64 │ Float64      │ Int64      │ Int64  │ String                   │
# ├─────┼─────────┼───────────┼──────────────┼────────────┼─────────┼──────────────┼────────────┼────────┼──────────────────────────┤
# │ 1   │ 17.0    │ 8         │ 302.0        │ 140.0      │ 3449.0  │ 10.5         │ 70         │ 1      │ ford,torino              │
# │ 2   │ 15.0    │ 8         │ 429.0        │ 198.0      │ 4341.0  │ 10.0         │ 70         │ 1      │ ford,galaxie,500         │
# │ 3   │ 10.0    │ 8         │ 360.0        │ 215.0      │ 4615.0  │ 14.0         │ 70         │ 1      │ ford,f250                │
# │ 4   │ 14.0    │ 8         │ 351.0        │ 153.0      │ 4154.0  │ 13.5         │ 71         │ 1      │ ford,galaxie,500         │
# │ 5   │ 13.0    │ 8         │ 400.0        │ 170.0      │ 4746.0  │ 12.0         │ 71         │ 1      │ ford,country,squire,(sw) │
# │ 6   │ 14.0    │ 8         │ 351.0        │ 153.0      │ 4129.0  │ 13.0         │ 72         │ 1      │ ford,galaxie,500         │
# │ 7   │ 13.0    │ 8         │ 302.0        │ 140.0      │ 4294.0  │ 16.0         │ 72         │ 1      │ ford,gran,torino,(sw)    │
# │ 8   │ 14.0    │ 8         │ 302.0        │ 137.0      │ 4042.0  │ 14.5         │ 73         │ 1      │ ford,gran,torino         │
# │ 9   │ 13.0    │ 8         │ 351.0        │ 158.0      │ 4363.0  │ 13.0         │ 73         │ 1      │ ford,ltd                 │
# │ 10  │ 12.0    │ 8         │ 400.0        │ 167.0      │ 4906.0  │ 12.5         │ 73         │ 1      │ ford,country             │
# │ 11  │ 16.0    │ 8         │ 302.0        │ 140.0      │ 4141.0  │ 14.0         │ 74         │ 1      │ ford,gran,torino         │
# │ 12  │ 14.0    │ 8         │ 302.0        │ 140.0      │ 4638.0  │ 16.0         │ 74         │ 1      │ ford,gran,torino,(sw)    │
# │ 13  │ 14.0    │ 8         │ 351.0        │ 148.0      │ 4657.0  │ 13.5         │ 75         │ 1      │ ford,ltd                 │
# │ 14  │ 13.0    │ 8         │ 302.0        │ 129.0      │ 3169.0  │ 12.0         │ 75         │ 1      │ ford,mustang,ii          │
# │ 15  │ 14.5    │ 8         │ 351.0        │ 152.0      │ 4215.0  │ 12.8         │ 76         │ 1      │ ford,gran,torino         │
# │ 16  │ 13.0    │ 8         │ 302.0        │ 130.0      │ 3870.0  │ 15.0         │ 76         │ 1      │ ford,f108                │
# │ 17  │ 16.0    │ 8         │ 351.0        │ 149.0      │ 4335.0  │ 14.5         │ 77         │ 1      │ ford,thunderbird         │
# │ 18  │ 18.1    │ 8         │ 302.0        │ 139.0      │ 3205.0  │ 11.2         │ 78         │ 1      │ ford,futura              │
# │ 19  │ 17.6    │ 8         │ 302.0        │ 129.0      │ 3725.0  │ 13.4         │ 79         │ 1      │ ford,ltd,landau          │
# │ 20  │ 15.5    │ 8         │ 351.0        │ 142.0      │ 4054.0  │ 14.3         │ 79         │ 1      │ ford,country,squire,(sw) │
# ⋮
# Last Group (16 rows): cylinders = 4
# │ Row │ mpg     │ cylinders │ displacement │ horsepower │ weight  │ acceleration │ model_year │ origin │ car_name             │
# │     │ Float64 │ Int64     │ Float64      │ Float64    │ Float64 │ Float64      │ Int64      │ Int64  │ String               │
# ├─────┼─────────┼───────────┼──────────────┼────────────┼─────────┼──────────────┼────────────┼────────┼──────────────────────┤
# │ 1   │ 21.0    │ 4         │ 122.0        │ 86.0       │ 2226.0  │ 16.5         │ 72         │ 1      │ ford,pinto,runabout  │
# │ 2   │ 22.0    │ 4         │ 122.0        │ 86.0       │ 2395.0  │ 16.0         │ 72         │ 1      │ ford,pinto,(sw)      │
# │ 3   │ 19.0    │ 4         │ 122.0        │ 85.0       │ 2310.0  │ 18.5         │ 73         │ 1      │ ford,pinto           │
# │ 4   │ 26.0    │ 4         │ 122.0        │ 80.0       │ 2451.0  │ 16.5         │ 74         │ 1      │ ford,pinto           │
# │ 5   │ 23.0    │ 4         │ 140.0        │ 83.0       │ 2639.0  │ 17.0         │ 75         │ 1      │ ford,pinto           │
# │ 6   │ 26.5    │ 4         │ 140.0        │ 72.0       │ 2565.0  │ 13.6         │ 76         │ 1      │ ford,pinto           │
# │ 7   │ 25.5    │ 4         │ 140.0        │ 89.0       │ 2755.0  │ 15.8         │ 77         │ 1      │ ford,mustang,ii,2+2  │
# │ 8   │ 36.1    │ 4         │ 98.0         │ 66.0       │ 1800.0  │ 14.4         │ 78         │ 1      │ ford,fiesta          │
# │ 9   │ 25.1    │ 4         │ 140.0        │ 88.0       │ 2720.0  │ 15.4         │ 78         │ 1      │ ford,fairmont,(man)  │
# │ 10  │ 22.3    │ 4         │ 140.0        │ 88.0       │ 2890.0  │ 17.3         │ 79         │ 1      │ ford,fairmont,4      │
# │ 11  │ 26.4    │ 4         │ 140.0        │ 88.0       │ 2870.0  │ 18.1         │ 80         │ 1      │ ford,fairmont        │
# │ 12  │ 34.4    │ 4         │ 98.0         │ 65.0       │ 2045.0  │ 16.2         │ 81         │ 1      │ ford,escort,4w       │
# │ 13  │ 29.9    │ 4         │ 98.0         │ 65.0       │ 2380.0  │ 20.7         │ 81         │ 1      │ ford,escort,2h       │
# │ 14  │ 24.0    │ 4         │ 140.0        │ 92.0       │ 2865.0  │ 16.4         │ 82         │ 1      │ ford,fairmont,futura │
# │ 15  │ 27.0    │ 4         │ 140.0        │ 86.0       │ 2790.0  │ 15.6         │ 82         │ 1      │ ford,mustang,gl      │
# │ 16  │ 28.0    │ 4         │ 120.0        │ 79.0       │ 2625.0  │ 18.6         │ 82         │ 1      │ ford,ranger          │

# %% [markdown]
# (8) make a scatter plot for all Ford automobiles such that:
#
# * each point represents an automobile
# * x-axis is horsepower
# * y-axis is mpg (miles per gallon)
# * x-axis, and y-axis are labeled.
# * title is "Fords"
# * automobiles with different numbers of cylinders are depicted by different markers and different colors, and automobiles with the same number of cylinders share the same marker and color. for example:
#     * 4 cylinders, use `marker="o"` and `color="C0"`
#     * 6 cylinders, use `marker="s"` and `color="C1"`
#     * 8 cylinders, use `marker="+"` and `color="C2"`
#     I suggest a `Dict` to map the number of cylinders to a marker.
# * a legend depicts the symbol and color for each number of cylinders

# %%
figure()
xlabel("horsepower")
ylabel("mpg")
title("Fords")

markers = Dict(4=> "o", 6=> "s", 8=> "+")
colors = Dict(4=> "C0", 6=> "C1", 8=> "C2")

for df_cyl in groupby(df_ford, :cylinders)
    num_cylinder = df_cyl[1, :cylinders]
    scatter(df_cyl[:, :horsepower], df_cyl[:, :mpg], 
        marker=markers[num_cylinder], color=colors[num_cylinder], label=num_cylinder) 
end
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x00000000355624A8>

# %% [markdown]
# # ramen
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/fc/Soy_ramen.jpg" width=200>
#
# see `ramen-ratings.csv`.
#
# > "The Ramen Rater is a product review website for the hardcore ramen enthusiast, with over 2500 reviews to date. Each record in the dataset is a single ramen product review. Review numbers are contiguous: more recently reviewed ramen varieties have higher numbers. Brand, Variety (the product name), Country, and Style (Cup? Bowl? Tray?) are pretty self-explanatory. Stars indicate the ramen quality, as assessed by the reviewer, on a 5-point scale; this is the most important column in the dataset!"
#
# The `:top_ten` ramen attribute is `missing` if the ramen never placed in the top ten; if it is not `missing`, the `:top_ten` attribute gives us the year it placed in the top ten and its place.
#
# source: [Kaggle](https://www.kaggle.com/residentmario/ramen-ratings/data)
#
# (1) read in `ramen-ratings.csv` as a `DataFrame`. display only the first six rows.

# %%
df_ramen = CSV.read("ramen-ratings.csv", copycols=true)
# Out:
# 2580×7 DataFrame
# │ Row  │ review_id │ brand          │ variety                                                               │ style   │ country     │ stars  │ top_ten │
# │      │ Int64     │ String         │ String                                                                │ String⍰ │ String      │ String │ String⍰ │
# ├──────┼───────────┼────────────────┼───────────────────────────────────────────────────────────────────────┼─────────┼─────────────┼────────┼─────────┤
# │ 1    │ 2580      │ New Touch      │ T's Restaurant Tantanmen                                              │ Cup     │ Japan       │ 3.75   │ missing │
# │ 2    │ 2579      │ Just Way       │ Noodles Spicy Hot Sesame Spicy Hot Sesame Guan-miao Noodles           │ Pack    │ Taiwan      │ 1      │ missing │
# │ 3    │ 2578      │ Nissin         │ Cup Noodles Chicken Vegetable                                         │ Cup     │ USA         │ 2.25   │ missing │
# │ 4    │ 2577      │ Wei Lih        │ GGE Ramen Snack Tomato Flavor                                         │ Pack    │ Taiwan      │ 2.75   │ missing │
# │ 5    │ 2576      │ Ching's Secret │ Singapore Curry                                                       │ Pack    │ India       │ 3.75   │ missing │
# │ 6    │ 2575      │ Samyang Foods  │ Kimchi song Song Ramen                                                │ Pack    │ South Korea │ 4.75   │ missing │
# │ 7    │ 2574      │ Acecook        │ Spice Deli Tantan Men With Cilantro                                   │ Cup     │ Japan       │ 4      │ missing │
# │ 8    │ 2573      │ Ikeda Shoku    │ Nabeyaki Kitsune Udon                                                 │ Tray    │ Japan       │ 3.75   │ missing │
# │ 9    │ 2572      │ Ripe'n'Dry     │ Hokkaido Soy Sauce Ramen                                              │ Pack    │ Japan       │ 0.25   │ missing │
# │ 10   │ 2571      │ KOKA           │ The Original Spicy Stir-Fried Noodles                                 │ Pack    │ Singapore   │ 2.5    │ missing │
# ⋮
# │ 2570 │ 11        │ Six Fortune    │ Chicken Flavor Instant Soup Noodle                                    │ Pack    │ South Korea │ 2      │ missing │
# │ 2571 │ 10        │ Smack          │ Vegetable Beef                                                        │ Pack    │ USA         │ 1.5    │ missing │
# │ 2572 │ 9         │ Sutah          │ Cup Noodle                                                            │ Cup     │ South Korea │ 2      │ missing │
# │ 2573 │ 8         │ Tung-I         │ Chinese Beef Instant Rice Noodle                                      │ Pack    │ Taiwan      │ 3      │ missing │
# │ 2574 │ 7         │ Ve Wong        │ Mushroom Pork                                                         │ Pack    │ Vietnam     │ 1      │ missing │
# │ 2575 │ 6         │ Vifon          │ Nam Vang                                                              │ Pack    │ Vietnam     │ 2.5    │ missing │
# │ 2576 │ 5         │ Vifon          │ Hu Tiu Nam Vang ["Phnom Penh" style] Asian Style Instant Rice Noodles │ Bowl    │ Vietnam     │ 3.5    │ missing │
# │ 2577 │ 4         │ Wai Wai        │ Oriental Style Instant Noodles                                        │ Pack    │ Thailand    │ 1      │ missing │
# │ 2578 │ 3         │ Wai Wai        │ Tom Yum Shrimp                                                        │ Pack    │ Thailand    │ 2      │ missing │
# │ 2579 │ 2         │ Wai Wai        │ Tom Yum Chili Flavor                                                  │ Pack    │ Thailand    │ 2      │ missing │
# │ 2580 │ 1         │ Westbrae       │ Miso Ramen                                                            │ Pack    │ USA         │ 0.5    │ missing │

# %% [markdown]
# (2) how many ratings are in the data set?

# %%
length(df_ramen[:, :review_id])
# Out:
# 2580

# %% [markdown]
# (3) oddly, the `:stars` column appears as an array of `String`s!
#
# This is because `"Unrated"` appears as the `:stars` attribute in a few rows and prevents `CSV.jl` from reading in the `:stars` column as all `Float64`s.
#
# `filter!` out the rows of the `DataFrame` that have `"Unrated"` as the `:stars` attribute.

# %%
#df_ford = filter(row -> occursin("ford", row[:car_name]) == true, df_auto)
filter!(row -> occursin("Unrated", row[:stars]) == false, df_ramen)
df_ramen
# Out:
# 2577×7 DataFrame
# │ Row  │ review_id │ brand          │ variety                                                               │ style   │ country     │ stars  │ top_ten │
# │      │ Int64     │ String         │ String                                                                │ String⍰ │ String      │ String │ String⍰ │
# ├──────┼───────────┼────────────────┼───────────────────────────────────────────────────────────────────────┼─────────┼─────────────┼────────┼─────────┤
# │ 1    │ 2580      │ New Touch      │ T's Restaurant Tantanmen                                              │ Cup     │ Japan       │ 3.75   │ missing │
# │ 2    │ 2579      │ Just Way       │ Noodles Spicy Hot Sesame Spicy Hot Sesame Guan-miao Noodles           │ Pack    │ Taiwan      │ 1      │ missing │
# │ 3    │ 2578      │ Nissin         │ Cup Noodles Chicken Vegetable                                         │ Cup     │ USA         │ 2.25   │ missing │
# │ 4    │ 2577      │ Wei Lih        │ GGE Ramen Snack Tomato Flavor                                         │ Pack    │ Taiwan      │ 2.75   │ missing │
# │ 5    │ 2576      │ Ching's Secret │ Singapore Curry                                                       │ Pack    │ India       │ 3.75   │ missing │
# │ 6    │ 2575      │ Samyang Foods  │ Kimchi song Song Ramen                                                │ Pack    │ South Korea │ 4.75   │ missing │
# │ 7    │ 2574      │ Acecook        │ Spice Deli Tantan Men With Cilantro                                   │ Cup     │ Japan       │ 4      │ missing │
# │ 8    │ 2573      │ Ikeda Shoku    │ Nabeyaki Kitsune Udon                                                 │ Tray    │ Japan       │ 3.75   │ missing │
# │ 9    │ 2572      │ Ripe'n'Dry     │ Hokkaido Soy Sauce Ramen                                              │ Pack    │ Japan       │ 0.25   │ missing │
# │ 10   │ 2571      │ KOKA           │ The Original Spicy Stir-Fried Noodles                                 │ Pack    │ Singapore   │ 2.5    │ missing │
# ⋮
# │ 2567 │ 11        │ Six Fortune    │ Chicken Flavor Instant Soup Noodle                                    │ Pack    │ South Korea │ 2      │ missing │
# │ 2568 │ 10        │ Smack          │ Vegetable Beef                                                        │ Pack    │ USA         │ 1.5    │ missing │
# │ 2569 │ 9         │ Sutah          │ Cup Noodle                                                            │ Cup     │ South Korea │ 2      │ missing │
# │ 2570 │ 8         │ Tung-I         │ Chinese Beef Instant Rice Noodle                                      │ Pack    │ Taiwan      │ 3      │ missing │
# │ 2571 │ 7         │ Ve Wong        │ Mushroom Pork                                                         │ Pack    │ Vietnam     │ 1      │ missing │
# │ 2572 │ 6         │ Vifon          │ Nam Vang                                                              │ Pack    │ Vietnam     │ 2.5    │ missing │
# │ 2573 │ 5         │ Vifon          │ Hu Tiu Nam Vang ["Phnom Penh" style] Asian Style Instant Rice Noodles │ Bowl    │ Vietnam     │ 3.5    │ missing │
# │ 2574 │ 4         │ Wai Wai        │ Oriental Style Instant Noodles                                        │ Pack    │ Thailand    │ 1      │ missing │
# │ 2575 │ 3         │ Wai Wai        │ Tom Yum Shrimp                                                        │ Pack    │ Thailand    │ 2      │ missing │
# │ 2576 │ 2         │ Wai Wai        │ Tom Yum Chili Flavor                                                  │ Pack    │ Thailand    │ 2      │ missing │
# │ 2577 │ 1         │ Westbrae       │ Miso Ramen                                                            │ Pack    │ USA         │ 0.5    │ missing │

# %% [markdown]
# (4) the `:stars` column still appears as `String`s. Convert it to `Float64`s by using `parse`, which works as follows:
#
# ```julia
# parse(Float64, "3.76") # get 3.76 as a Float64
# ```
#
# You can do this to the entire column vector by preceding with `.`:
#
# ```julia
# df[!, :stars] = parse.(Float64, df[:, :stars])
# ```

# %%
df_ramen[!, :stars] = parse.(Float64, df_ramen[:, :stars])
# Out:
# 2577-element Array{Float64,1}:
#  3.75
#  1.0
#  2.25
#  2.75
#  3.75
#  4.75
#  4.0
#  3.75
#  0.25
#  2.5
#  5.0
#  5.0
#  4.25
#  ⋮
#  2.5
#  2.0
#  1.5
#  2.0
#  3.0
#  1.0
#  2.5
#  3.5
#  1.0
#  2.0
#  2.0
#  0.5

# %% [markdown]
# (5) What is the highest rated variety of ramen that satisfies the following attributes:
# * "Nissin" brand
# * mentions "Beef" in the variety
# * "Pack" style

# %%
df_brand = filter(row-> row[:brand] == "Nissin", df_ramen)
df_beef = filter(row -> occursin("Beef", row[:variety]) == true, df_brand)
df_style = filter(row -> row[:style] == "Pack", df_beef)
highest_rating = maximum(df_style[:, :stars])
print(filter(row -> row[:stars] == highest_rating, df_style))
# Out:
# 1×7 DataFrame
# │ Row │ review_id │ brand  │ variety                                      │ style   │ country   │ stars   │ top_ten │
# │     │ Int64     │ String │ String                                       │ String⍰ │ String    │ Float64 │ String⍰ │
# ├─────┼───────────┼────────┼──────────────────────────────────────────────┼─────────┼───────────┼─────────┼─────────┤
# │ 1   │ 1448      │ Nissin │ Premium Instant Noodles Roasted Beef Flavour │ Pack    │ Singapore │ 4.25    │ missing │

# %% [markdown]
# (6) ramen from how many different countries is rated?

# %%
num_countries = length(unique(df_ramen[:, :country]))
# Out:
# 37

# %% [markdown]
# (7) use `by` to:
# * split the `DataFrame` into groups, partitioned by `:country`
# * apply a function to a column that counts the number of rows
# * combine the result into one `DataFrame` with a new column `:nb_ratings`
#
# i.e., use `by` to create a new `DataFrame`, `df_by_country`:
#
# ```
# :country :nb_ratings
# Japan    352
# USA      324
# ...
# ```
#
# You should indeed see that 352 ramens from Japan were rated and 324 ramens from the USA were rated.

# %%
df_by_country = by(df_ramen, :country, nb_ratings=:country=>length)
# Out:
# 37×2 DataFrame
# │ Row │ country     │ nb_ratings │
# │     │ String      │ Int64      │
# ├─────┼─────────────┼────────────┤
# │ 1   │ Japan       │ 352        │
# │ 2   │ Taiwan      │ 224        │
# │ 3   │ USA         │ 324        │
# │ 4   │ India       │ 31         │
# │ 5   │ South Korea │ 307        │
# │ 6   │ Singapore   │ 109        │
# │ 7   │ Thailand    │ 191        │
# │ 8   │ Hong Kong   │ 137        │
# │ 9   │ Vietnam     │ 108        │
# │ 10  │ Ghana       │ 2          │
# ⋮
# │ 27  │ Netherlands │ 15         │
# │ 28  │ Cambodia    │ 5          │
# │ 29  │ Finland     │ 3          │
# │ 30  │ Sarawak     │ 3          │
# │ 31  │ Philippines │ 47         │
# │ 32  │ Sweden      │ 3          │
# │ 33  │ Colombia    │ 6          │
# │ 34  │ Estonia     │ 2          │
# │ 35  │ Holland     │ 4          │
# │ 36  │ Poland      │ 4          │
# │ 37  │ Dubai       │ 3          │

# %% [markdown]
# (8) `sort!` the rows in `df_by_country` from (6) by the number of ratings for ramens from that country *from most to least*

# %%
sort!(df_by_country, :nb_ratings, rev = true)
# Out:
# 37×2 DataFrame
# │ Row │ country     │ nb_ratings │
# │     │ String      │ Int64      │
# ├─────┼─────────────┼────────────┤
# │ 1   │ Japan       │ 352        │
# │ 2   │ USA         │ 324        │
# │ 3   │ South Korea │ 307        │
# │ 4   │ Taiwan      │ 224        │
# │ 5   │ Thailand    │ 191        │
# │ 6   │ China       │ 169        │
# │ 7   │ Malaysia    │ 155        │
# │ 8   │ Hong Kong   │ 137        │
# │ 9   │ Indonesia   │ 126        │
# │ 10  │ Singapore   │ 109        │
# ⋮
# │ 27  │ Cambodia    │ 5          │
# │ 28  │ Fiji        │ 4          │
# │ 29  │ Holland     │ 4          │
# │ 30  │ Poland      │ 4          │
# │ 31  │ Finland     │ 3          │
# │ 32  │ Sarawak     │ 3          │
# │ 33  │ Sweden      │ 3          │
# │ 34  │ Dubai       │ 3          │
# │ 35  │ Ghana       │ 2          │
# │ 36  │ Estonia     │ 2          │
# │ 37  │ Nigeria     │ 1          │

# %% [markdown]
# (9) using `df_by_country`, construct a bar plot depicting the number of ratings of ramen from each country:
# * one bar for each country
# * height of the bar is the number of ratings ramen from that country received
# * the countries appear on the bar plot in order of the number of ratings received
# * replace numeric x-tick labels on the bar plot with the name of each country. to see the labels, you will need to make the labels run vertically via passing `rotation=90` to `xticks()`

# %%
figure()
bar(1:num_countries, df_by_country[!, :nb_ratings])
xticks(1:num_countries, df_by_country[!, :country], rotation=90)

xlabel("Countries")
ylabel("Number of Ratings")
title("Number of Rating in each Country")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1, 'Number of Rating in each Country')

# %% [markdown]
# (10) now let's see where the top ten ramens tend to come from.
# create a new `DataFrame`, `df_top_ten`, by dropping all rows that have a `missing` value in `:top_ten`. (we're no longer using our `df_by_country` from above) the `filter` function will be useful.

# %%
df_top_ten = filter(row -> ismissing(row[:top_ten]) == false, df_ramen)
df_ramen
# Out:
# 2548×7 DataFrame
# │ Row  │ review_id │ brand          │ variety                                                               │ style   │ country     │ stars   │ top_ten │
# │      │ Int64     │ String         │ String                                                                │ String⍰ │ String      │ Float64 │ String⍰ │
# ├──────┼───────────┼────────────────┼───────────────────────────────────────────────────────────────────────┼─────────┼─────────────┼─────────┼─────────┤
# │ 1    │ 2580      │ New Touch      │ T's Restaurant Tantanmen                                              │ Cup     │ Japan       │ 3.75    │ missing │
# │ 2    │ 2579      │ Just Way       │ Noodles Spicy Hot Sesame Spicy Hot Sesame Guan-miao Noodles           │ Pack    │ Taiwan      │ 1.0     │ missing │
# │ 3    │ 2578      │ Nissin         │ Cup Noodles Chicken Vegetable                                         │ Cup     │ USA         │ 2.25    │ missing │
# │ 4    │ 2577      │ Wei Lih        │ GGE Ramen Snack Tomato Flavor                                         │ Pack    │ Taiwan      │ 2.75    │ missing │
# │ 5    │ 2576      │ Ching's Secret │ Singapore Curry                                                       │ Pack    │ India       │ 3.75    │ missing │
# │ 6    │ 2575      │ Samyang Foods  │ Kimchi song Song Ramen                                                │ Pack    │ South Korea │ 4.75    │ missing │
# │ 7    │ 2574      │ Acecook        │ Spice Deli Tantan Men With Cilantro                                   │ Cup     │ Japan       │ 4.0     │ missing │
# │ 8    │ 2573      │ Ikeda Shoku    │ Nabeyaki Kitsune Udon                                                 │ Tray    │ Japan       │ 3.75    │ missing │
# │ 9    │ 2572      │ Ripe'n'Dry     │ Hokkaido Soy Sauce Ramen                                              │ Pack    │ Japan       │ 0.25    │ missing │
# │ 10   │ 2571      │ KOKA           │ The Original Spicy Stir-Fried Noodles                                 │ Pack    │ Singapore   │ 2.5     │ missing │
# ⋮
# │ 2538 │ 11        │ Six Fortune    │ Chicken Flavor Instant Soup Noodle                                    │ Pack    │ South Korea │ 2.0     │ missing │
# │ 2539 │ 10        │ Smack          │ Vegetable Beef                                                        │ Pack    │ USA         │ 1.5     │ missing │
# │ 2540 │ 9         │ Sutah          │ Cup Noodle                                                            │ Cup     │ South Korea │ 2.0     │ missing │
# │ 2541 │ 8         │ Tung-I         │ Chinese Beef Instant Rice Noodle                                      │ Pack    │ Taiwan      │ 3.0     │ missing │
# │ 2542 │ 7         │ Ve Wong        │ Mushroom Pork                                                         │ Pack    │ Vietnam     │ 1.0     │ missing │
# │ 2543 │ 6         │ Vifon          │ Nam Vang                                                              │ Pack    │ Vietnam     │ 2.5     │ missing │
# │ 2544 │ 5         │ Vifon          │ Hu Tiu Nam Vang ["Phnom Penh" style] Asian Style Instant Rice Noodles │ Bowl    │ Vietnam     │ 3.5     │ missing │
# │ 2545 │ 4         │ Wai Wai        │ Oriental Style Instant Noodles                                        │ Pack    │ Thailand    │ 1.0     │ missing │
# │ 2546 │ 3         │ Wai Wai        │ Tom Yum Shrimp                                                        │ Pack    │ Thailand    │ 2.0     │ missing │
# │ 2547 │ 2         │ Wai Wai        │ Tom Yum Chili Flavor                                                  │ Pack    │ Thailand    │ 2.0     │ missing │
# │ 2548 │ 1         │ Westbrae       │ Miso Ramen                                                            │ Pack    │ USA         │ 0.5     │ missing │

# %% [markdown]
# (11) use `by` to count the number of top ten ramens from each country and make a bar plot showing where the top ten ramens come from. this is just like in (8), except for top ten ramens only. to distinguish from the bar plot in (8):
# * use a different color for the bars
# * put a title on the plot "top ten ramens"

# %%
df_top_ten = by(df_top_ten, :country, nb_top_ten=:top_ten=>length)
sort!(df_top_ten, :nb_top_ten, rev=true)
# Out:
# 11×2 DataFrame
# │ Row │ country     │ nb_top_ten │
# │     │ String      │ Int64      │
# ├─────┼─────────────┼────────────┤
# │ 1   │ Singapore   │ 7          │
# │ 2   │ Japan       │ 6          │
# │ 3   │ Malaysia    │ 6          │
# │ 4   │ South Korea │ 5          │
# │ 5   │ Indonesia   │ 4          │
# │ 6   │ Thailand    │ 3          │
# │ 7   │ Taiwan      │ 2          │
# │ 8   │ USA         │ 1          │
# │ 9   │ Hong Kong   │ 1          │
# │ 10  │ China       │ 1          │
# │ 11  │ Myanmar     │ 1          │

# %%
figure()
bar(1:length(df_top_ten[!, :country]), df_top_ten[!, :nb_top_ten], color= "C1")
xticks(1:length(df_top_ten[!, :country]),df_top_ten[!, :country], rotation=90)
xlabel("Country")
ylabel("Number of Top Ten Ratings")
title("Top Ten Ramens")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1, 'Top Ten Ramens')

# %% [markdown]
# (12) Singapore, Japan, Malaysia, and South Korea have a lot of ramens in the top ten. let's compare the ratings that ramen receive from these four countries. first, `filter!` out of the ratings `DataFrame` all ramens that are not from these four countries.

# %%
df_top_ramen = filter(row -> row[:nb_top_ten].>= 5, df_top_ten)
# Out:
# 4×2 DataFrame
# │ Row │ country     │ nb_top_ten │
# │     │ String      │ Int64      │
# ├─────┼─────────────┼────────────┤
# │ 1   │ Singapore   │ 7          │
# │ 2   │ Japan       │ 6          │
# │ 3   │ Malaysia    │ 6          │
# │ 4   │ South Korea │ 5          │

# %%
filter!(row->row[:country] in df_top_ramen[:country], df_ramen)
df_ramen
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = (::getfield(Main, Symbol("##25#26")))(::DataFrameRow{DataFrame,DataFrames.Index}) at In[33]:1
# └ @ Main .\In[33]:1
# 923×7 DataFrame
# │ Row │ review_id │ brand           │ variety                               │ style   │ country     │ stars   │ top_ten │
# │     │ Int64     │ String          │ String                                │ String⍰ │ String      │ Float64 │ String⍰ │
# ├─────┼───────────┼─────────────────┼───────────────────────────────────────┼─────────┼─────────────┼─────────┼─────────┤
# │ 1   │ 2580      │ New Touch       │ T's Restaurant Tantanmen              │ Cup     │ Japan       │ 3.75    │ missing │
# │ 2   │ 2575      │ Samyang Foods   │ Kimchi song Song Ramen                │ Pack    │ South Korea │ 4.75    │ missing │
# │ 3   │ 2574      │ Acecook         │ Spice Deli Tantan Men With Cilantro   │ Cup     │ Japan       │ 4.0     │ missing │
# │ 4   │ 2573      │ Ikeda Shoku     │ Nabeyaki Kitsune Udon                 │ Tray    │ Japan       │ 3.75    │ missing │
# │ 5   │ 2572      │ Ripe'n'Dry      │ Hokkaido Soy Sauce Ramen              │ Pack    │ Japan       │ 0.25    │ missing │
# │ 6   │ 2571      │ KOKA            │ The Original Spicy Stir-Fried Noodles │ Pack    │ Singapore   │ 2.5     │ missing │
# │ 7   │ 2568      │ Nongshim        │ Mr. Bibim Stir-Fried Kimchi Flavor    │ Pack    │ South Korea │ 4.25    │ missing │
# │ 8   │ 2567      │ Nissin          │ Deka Buto Kimchi Pork Flavor          │ Bowl    │ Japan       │ 4.5     │ missing │
# │ 9   │ 2565      │ KOKA            │ Mushroom Flavour Instant Noodles      │ Cup     │ Singapore   │ 3.5     │ missing │
# │ 10  │ 2561      │ Paldo           │ Premium Gomtang                       │ Pack    │ South Korea │ 4.0     │ missing │
# ⋮
# │ 913 │ 21        │ Nongshim        │ Champong Oriental Noodles             │ Pack    │ South Korea │ 4.0     │ missing │
# │ 914 │ 20        │ Nongshim        │ Neoguri (Seafood'n'Spicy)             │ Pack    │ South Korea │ 3.5     │ missing │
# │ 915 │ 19        │ Nongshim        │ Shin Ramyun                           │ Pack    │ South Korea │ 4.0     │ missing │
# │ 916 │ 18        │ Ottogi          │ Jin Ramen (Hot Taste)                 │ Pack    │ South Korea │ 3.5     │ missing │
# │ 917 │ 16        │ Samyang         │ Kalgug-Su (Spicy)                     │ Pack    │ South Korea │ 3.5     │ missing │
# │ 918 │ 15        │ Samyang         │ Pojangmacha U-dong                    │ Pack    │ South Korea │ 2.5     │ missing │
# │ 919 │ 14        │ Samyang         │ Hot                                   │ Pack    │ South Korea │ 3.5     │ missing │
# │ 920 │ 13        │ Sapporo Ichiban │ Chow Mein                             │ Pack    │ Japan       │ 5.0     │ 2012 #4 │
# │ 921 │ 12        │ Sapporo Ichiban │ Shrimp Flavor                         │ Pack    │ Japan       │ 2.5     │ missing │
# │ 922 │ 11        │ Six Fortune     │ Chicken Flavor Instant Soup Noodle    │ Pack    │ South Korea │ 2.0     │ missing │
# │ 923 │ 9         │ Sutah           │ Cup Noodle                            │ Cup     │ South Korea │ 2.0     │ missing │

# %% [markdown]
# (13) use `groupby` to group by country, loop through the groups, and plot histograms of the ratings for ramen from each country on the same plot with four panels that have a shared x- and y-axis. I included some skeleton code below. See `subplots` [here](https://matplotlib.org/3.1.1/gallery/statistics/hist.html).

# %%
df_r
# Out:
# GroupedDataFrame with 4 groups based on key: country
# First Group (352 rows): country = "Japan"
# │ Row │ review_id │ brand           │ variety                                          │ style   │ country │ stars   │ top_ten │
# │     │ Int64     │ String          │ String                                           │ String⍰ │ String  │ Float64 │ String⍰ │
# ├─────┼───────────┼─────────────────┼──────────────────────────────────────────────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 2580      │ New Touch       │ T's Restaurant Tantanmen                         │ Cup     │ Japan   │ 3.75    │ missing │
# │ 2   │ 2574      │ Acecook         │ Spice Deli Tantan Men With Cilantro              │ Cup     │ Japan   │ 4.0     │ missing │
# │ 3   │ 2573      │ Ikeda Shoku     │ Nabeyaki Kitsune Udon                            │ Tray    │ Japan   │ 3.75    │ missing │
# │ 4   │ 2572      │ Ripe'n'Dry      │ Hokkaido Soy Sauce Ramen                         │ Pack    │ Japan   │ 0.25    │ missing │
# │ 5   │ 2567      │ Nissin          │ Deka Buto Kimchi Pork Flavor                     │ Bowl    │ Japan   │ 4.5     │ missing │
# │ 6   │ 2553      │ Nissin          │ Hakata Ramen Noodle White Tonkotsu               │ Bowl    │ Japan   │ 4.75    │ missing │
# │ 7   │ 2546      │ New Touch       │ Sugo-Men Kyoto Backfat Shoyu Ramen               │ Bowl    │ Japan   │ 3.75    │ missing │
# │ 8   │ 2542      │ Acecook         │ Super Cup Yochan Ika Yakisoba                    │ Tray    │ Japan   │ 1.5     │ missing │
# │ 9   │ 2534      │ Fujiwara        │ Hokkaido Hakodate Shoyu Ramen                    │ Pack    │ Japan   │ 4.0     │ missing │
# │ 10  │ 2532      │ Nissin          │ Nippon Onomichi Ramen                            │ Bowl    │ Japan   │ 4.75    │ missing │
# ⋮
# │ 342 │ 70        │ Nissin          │ Demae Ramen XO Sauce Seafood                     │ Pack    │ Japan   │ 4.0     │ missing │
# │ 343 │ 63        │ Nissin          │ Souper Meal Chicken Flavor With Vegetable Medley │ Bowl    │ Japan   │ 3.0     │ missing │
# │ 344 │ 31        │ Myojo           │ Ippeichan Yakisoba                               │ Tray    │ Japan   │ 4.0     │ 2013 #6 │
# │ 345 │ 30        │ Myojo           │ Special Duck                                     │ Pack    │ Japan   │ 1.0     │ missing │
# │ 346 │ 28        │ Nissin          │ Chikin Ramen                                     │ Pack    │ Japan   │ 5.0     │ missing │
# │ 347 │ 27        │ Nissin          │ Demae Ramen Curry Flavor                         │ Pack    │ Japan   │ 4.0     │ missing │
# │ 348 │ 26        │ Nissin          │ Soba Noodles With Mayo Mustard Squirt            │ Pack    │ Japan   │ 4.0     │ missing │
# │ 349 │ 25        │ Nissin          │ Demae Ramen Spicy Flavor                         │ Pack    │ Japan   │ 3.0     │ missing │
# │ 350 │ 24        │ Nissin          │ Demae Ramen Spicy Seafood With Chili Pepper      │ Pack    │ Japan   │ 2.0     │ missing │
# │ 351 │ 13        │ Sapporo Ichiban │ Chow Mein                                        │ Pack    │ Japan   │ 5.0     │ 2012 #4 │
# │ 352 │ 12        │ Sapporo Ichiban │ Shrimp Flavor                                    │ Pack    │ Japan   │ 2.5     │ missing │
# ⋮
# Last Group (155 rows): country = "Malaysia"
# │ Row │ review_id │ brand                  │ variety                                           │ style   │ country  │ stars   │ top_ten │
# │     │ Int64     │ String                 │ String                                            │ String⍰ │ String   │ Float64 │ String⍰ │
# ├─────┼───────────┼────────────────────────┼───────────────────────────────────────────────────┼─────────┼──────────┼─────────┼─────────┤
# │ 1   │ 2552      │ MyKuali                │ Penang White Curry Rice Vermicelli Soup           │ Bowl    │ Malaysia │ 5.0     │ missing │
# │ 2   │ 2510      │ MyKuali                │ Penang Red Tom Yum Goong Noodle                   │ Pack    │ Malaysia │ 5.0     │ missing │
# │ 3   │ 2500      │ The Ramen Rater Select │ Supreme Creamy Tom Yum Noodle                     │ Box     │ Malaysia │ 5.0     │ missing │
# │ 4   │ 2479      │ E-Zee                  │ Instant Noodles Chicken Flavour                   │ Pack    │ Malaysia │ 4.0     │ missing │
# │ 5   │ 2430      │ MyKuali                │ MeeKuali Bihun Sup Rempah Perisa Daging           │ Pack    │ Malaysia │ 5.0     │ missing │
# │ 6   │ 2392      │ MyKuali                │ Penang Red Tom Yum Goong Rice Vermicelli Soup     │ Bowl    │ Malaysia │ 5.0     │ missing │
# │ 7   │ 2377      │ MyKuali                │ Penang White Curry Instant Noodle (Japan Version) │ Box     │ Malaysia │ 5.0     │ missing │
# │ 8   │ 2299      │ Cintan                 │ Mi Segera Mmm... Original                         │ Pack    │ Malaysia │ 3.0     │ missing │
# │ 9   │ 2222      │ Nyor Nyar              │ Vegetarian Penang White Curry                     │ Pack    │ Malaysia │ 5.0     │ missing │
# │ 10  │ 2192      │ Nyor Nyar              │ Penang White Curry Instant Noodle                 │ Pack    │ Malaysia │ 5.0     │ missing │
# ⋮
# │ 145 │ 926       │ Ibumie                 │ VegeMee Vegetarian Flavour                        │ Pack    │ Malaysia │ 2.75    │ missing │
# │ 146 │ 923       │ Ibumie                 │ LadMee Hot Pepper                                 │ Pack    │ Malaysia │ 3.5     │ missing │
# │ 147 │ 906       │ Daddy                  │ Kari 365 Curry Flavour                            │ Pack    │ Malaysia │ 5.0     │ missing │
# │ 148 │ 844       │ Maggi                  │ 2 Minute Noodles Perencah Asam Laksa              │ Pack    │ Malaysia │ 4.0     │ missing │
# │ 149 │ 778       │ Mamee                  │ Express Cup Curry                                 │ Cup     │ Malaysia │ 2.5     │ missing │
# │ 150 │ 743       │ Mamee                  │ Express Cup Tom Yum                               │ Cup     │ Malaysia │ 3.75    │ missing │
# │ 151 │ 691       │ Mamee                  │ Express Cup Vegetarian                            │ Cup     │ Malaysia │ 2.0     │ missing │
# │ 152 │ 679       │ Mamee                  │ Express Cup Fried Onion Chicken                   │ Cup     │ Malaysia │ 3.25    │ missing │
# │ 153 │ 457       │ Ibumie                 │ Harmee Mee goreng Prawn                           │ Pack    │ Malaysia │ 4.5     │ missing │
# │ 154 │ 405       │ Ibumie                 │ Harmee Prawn                                      │ Pack    │ Malaysia │ 3.25    │ missing │
# │ 155 │ 190       │ Maggi                  │ Perencah Tom Yam                                  │ Pack    │ Malaysia │ 2.9     │ missing │

# %%
# pre-specify bins for each plot
bins = range(0.0, 5.0, length=10)

fig, axs = subplots(
    4, 
    1, 
    figsize=(12, 8), 
    sharex=true, 
    sharey=true, 
    tight_layout=false
)

#label_color = "C0"
df_r = groupby(df_ramen, :country)

for (i, data) in enumerate(df_r)
    country = data[1, :country]
    axs[i].hist(
        data[!, :stars], 
        color = "C$i",
        bins=bins,
    )
    
    axs[i].set_ylabel("# of Ratings")
    axs[i].text(
        -.2, 
        60,
        "$country", 
        alpha=0.35, 
        size=80, 
        zorder=-100, 
        color="C$i", 
        clip_on=true, 
        va="center", 
        weight="bold"
    )
    
end

suptitle(
    "Top Ramen Countries and Their Ratings",
    weight ="bold", 
    size = 12, 
    
)
xlabel(
    "Ramen Star Rating", 
    weight = "bold", 
    size = 15, 
   
)

subplots_adjust(top=0.9)
# Out:
# Figure(PyObject <Figure size 1200x800 with 4 Axes>)
