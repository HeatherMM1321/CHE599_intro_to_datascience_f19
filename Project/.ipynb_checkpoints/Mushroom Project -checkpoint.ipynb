# %%
using CSV
using DataFrames
using PyPlot
using ScikitLearn # machine learning package
using Statistics
using Random
using LaTeXStrings # for L"$x$" to work instead of needing to do "\$x\$"
using Printf

rcParams = PyPlot.PyDict(PyPlot.matplotlib."rcParams")
rcParams["font.size"] = 16
# Out:
# 16

# %% [markdown]
# # Is that Mushroom Edible????

# %% [markdown]
# The following project will be attempting to classify a species of mushroom as either poisonous or edible. The data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family. Each species is identied as definitely edible, definitely poisonous, or of unknown edibility and not recommended(labeled as poisonous). The goal is to use a _______ machine learning software to correctly predict whether or not a mushroom is edible. Each mushroom species in the data set has a classification along with 22 attributes listed below.
#
# Attribute Information:
#
# 1. cap-shape:
#         b=bell
#         c=conical
#         x=convex
#         f=flat
#         k=knobbed
#         s=knobbed
# 2. cap-surface:
#         f=fibrous
#         g=grooves
#         y=scaly
#         s=smooth
# 3. cap-color:
#         n=brown
#         b=buff
#         c=cinnamon
#         g=gray
#         r=green
#         p=pink
#         u=purple
#         e=red
#         w=white
#         y=yellow
# 4. bruises?:
#         t=bruises
#         f=no
# 5. odor:
#         a=almond
#         l=anise
#         c=creosote
#         y=fishy
#         f=foul
#         m=musty
#         n=none
#         p=pungent
#         s=spicy
# 6. gill-attachment:
#         a=attached
#         d=descending
#         f=free
#         n=notched
# 7. gill-spacing:
#         c=close
#         w=crowded
#         d=distant
# 8. gill-size:
#         b=broad
#         n=narrow
# 9. gill-color:
#         k=black
#         n=brown
#         b=buff
#         h=chocolate
#         g=gray
#         r=green
#         o=orange
#         p=pink
#         u=purple
#         e=red
#         w=white
#         y=yellow
# 10. stalk-shape:
#         e=enlarging
#         t=tapering
# 11. stalk-root:
#         b=bulbous
#         c=club
#         u=cup
#         e=equal
#         z=rhizomorphs
#         r=rooted
#         ?=missing
# 12. stalk-surface-above-ring:
#         f=fibrous
#         y=scaly
#         k=silky
#         s=smooth
# 13. stalk-surface-below-ring:
#         f=fibrous
#         y=scaly
#         k=silky
#         s=smooth
# 14. stalk-color-above-ring:
#         n=brown
#         b=buff
#         c=cinnamon
#         g=gray
#         o=orange
#         p=pink
#         e=red
#         w=white
#         y=yellow
# 15. stalk-color-below-ring:
#         n=brown
#         b=buff
#         c=cinnamon
#         g=gray
#         o=orange
#         p=pink
#         e=red
#         w=white
#         y=yellow
# 16. veil-type:
#         p=partial
#         u=universal
# 17. veil-color:
#         n=brown
#         o=orange
#         w=white
#         y=yellow
# 18. ring-number:
#         n=none
#         o=one
#         t=two
# 19. ring-type:
#         c=cobwebby
#         e=evanescent
#         f=flaring
#         l=large
#         n=none
#         p=pendant
#         s=sheathing
#         z=zone
# 20. spore-print-color:
#         k=black
#         n=brown
#         b=buff
#         h=chocolate
#         r=green
#         o=orange
#         u=purple
#         w=white
#         y=yellow
# 21. population:
#         a=abundant
#         c=clustered
#         n=numerous
#         s=scattered
#         v=several
#         y=solitary
# 22. habitat:
#         g=grasses
#         l=leaves
#         m=meadows
#         p=paths
#         u=urban
#         w=waste
#         d=woods
#
# The logical rules to determine whether a mushroom is edible or not that has proven to be the most successful are as follows.
#
#     P_1) odor=NOT(almond.OR.anise.OR.none)
# 	     120 poisonous cases missed, 98.52% accuracy
#
# 	P_2) spore-print-color=green
# 	     48 cases missed, 99.41% accuracy
#
# 	P_3) odor=none.AND.stalk-surface-below-ring=scaly.AND.
# 	          (stalk-color-above-ring=NOT.brown)
# 	     8 cases missed, 99.90% accuracy
#
# 	P_4) habitat=leaves.AND.cap-color=white
# 	         100% accuracy
#
# 	Rule P_4) may also be
#
# 	P_4') population=clustered.AND.cap_color=white

# %%
#here I have loaded in the data and specified that the dat begins on the 1st row so that I may asign headers 
df = CSV.read("agaricus-lepiota.data", datarow=1, copycols=true)

#I am assigning headers to each attribute 
df = names!(df, [:class, :cap_shape, :cap_surface, :cap_color, :bruises, :odor, :gill_attachment, :gill_spacing, :gill_size, 
        :gill_color, :stalk_shape, :stalk_root, :stalk_surface_above_ring, :stalk_surface_below_ring, :stalk_color_above_ring,
        :stalk_color_below_ring, :veil_type, :veil_color, :ring_number, :ring_type, :spore_print_color, :population, :habitat])

#just checking!
first(df, 6)
# Out:
# 6×23 DataFrame. Omitted printing of 17 columns
# │ Row │ class  │ cap_shape │ cap_surface │ cap_color │ bruises │ odor   │
# │     │ String │ String    │ String      │ String    │ String  │ String │
# ├─────┼────────┼───────────┼─────────────┼───────────┼─────────┼────────┤
# │ 1   │ p      │ x         │ s           │ n         │ t       │ p      │
# │ 2   │ e      │ x         │ s           │ y         │ t       │ a      │
# │ 3   │ e      │ b         │ s           │ w         │ t       │ l      │
# │ 4   │ p      │ x         │ y           │ w         │ t       │ p      │
# │ 5   │ e      │ x         │ s           │ g         │ f       │ n      │
# │ 6   │ e      │ x         │ y           │ y         │ t       │ a      │

# %% [markdown]
# Need to make all of this data binary

# %%
#creating the variabels 
n_mushrooms = nrow(df)
size = NaN*zeros(n_mushrooms)

df_mushrooms = DataFrame(
#class 
class = size,  #b

#cap_shape (1)
cap_shape_bell = size,  #b
cap_shape_conical = size,  #c
cap_shape_convex = size, #x
cap_shape_flat = size, #f
cap_shape_knobbed = size, #k
cap_shape_sunken = size, #s

#cap_surface (2)
cap_surface_fibrous = size, #f
cap_surface_grooves = size, #g
cap_surface_scaly = size, #y
cap_surface_smooth = size, #s

#cap_color (3)
cap_color_brown = size, #n 
cap_color_buff = size, #b
cap_color_cinnamon = size, #c
cap_color_gray = size, #g
cap_color_green = size, #r
cap_color_pink = size, #p
cap_color_purple = size, #u
cap_color_red = size, #e
cap_color_white = size, #w
cap_color_yellow = size, #y 

#bruises (4)
bruises_yes = size, #t 
bruises_no = size, #f

#odor (5)
odor_almond = size, #a
odor_anise = size, #l
odor_creosote = size, #c
odor_fishy = size, #f
odor_musty = size, #m
odor_none = size, #n
odor_pungent = size, #p
odor_spicy = size, #s

#gill_attachment (6)
gill_attachment_attached = size, #a
gill_attachment_descending = size, #d
gill_attachment_free = size, #f
gill_attachment_nothced = size, #n

#gill_spacing (7)
gill_spacing_close = size, #c
gill_spacing_crowded = size, #w
gill_spacing_distant = size, #d

#gill_size (8)
gill_size_broad = size, #b
gill_size_narrow = size, #n

#gill_color (9)
gill_color_black = size, #k
gill_color_brown = size, #n 
gill_color_buff = size, #b
gill_color_chocolate = size, #h
gill_color_gray = size, #g
gill_color_green = size, #r
gill_color_orange = size, #o
gill_color_pink = size, #p
gill_color_purple = size, #u
gill_color_red = size, #e
gill_color_white = size, #w
gill_color_yellow = size, #y 

#stalk_shape (10)
stalk_shape_enlarging = size, #e
stalk_shape_tapering = size, #t

#stalk_root (11)
stalk_root_bublous = size, #b
stalk_root_club = size, #c
stalk_root_cup =size, #u
stalk_root_equal = size, #e
stalk_root_rhizomorphs = size, #z
stalk_root_rooted = size, #r
stalk_root_missing = size, #?

#stalk_surface_above_ring (12)
stalk_surface_above_ring_fibrous = size, #f
stalk_surface_above_ring_scaly = size, #y
stalk_surface_above_ring_silky = size,#k
stalk_surface_above_ring_smooth = size, #s

#stalk_surface_below_ring (13)
stalk_surface_below_ring_fibrous = size, #f
stalk_surface_below_ring_scaly = size, #y
stalk_surface_below_ring_silky = size, #k
stalk_surface_below_ring_smooth = size, #s

#stalk_color_above_ring (14)
stalk_color_above_ring_brown = size, #n
stalk_color_above_ring_buff = size, #b
stalk_color_above_ring_cinnamon = size, #c
stalk_color_above_ring_gray = size, #g
stalk_color_above_ring_orange = size, #o
stalk_color_above_ring_pink = size, #p
stalk_color_above_ring_red = size, #e
stalk_color_above_ring_white = size, #w
stalk_color_above_ring_yellow = size, #y

#stalk_color_below_ring (15)
stalk_color_below_ring_brown = size, #n
stalk_color_below_ring_buff = size, #b
stalk_color_below_ring_cinnamon = size, #c
stalk_color_below_ring_gray = size, #g
stalk_color_below_ring_orange = size, #o
stalk_color_below_ring_pink = size, #p
stalk_color_below_ring_red = size, #e
stalk_color_below_ring_white = size, #w
stalk_color_below_ring_yellow = size, #y

#veil_Type (16)
veil_type_partial = size, #p
veil_type_universal = size, #u

#veil color (17)
veil_color_brown = size, #n
veil_color_orange = size, #o
veil_color_white = size, #w
veil_color_yellow = size, #y

#ring_number (18)
ring_number_none = size, #n
ring_number_one = size, #o
ring_number_two = size, #t

#ring_type (19)
ring_type_cobwebby = size, #c
ring_type_evanescent = size, #e
ring_type_flaring =size, #f
ring_type_large = size, #l
ring_type_none = size, #n
ring_type_pendant = size, #p
ring_type_sheathing = size, #s
ring_type_zone = size, #z

#spore_print_color (20)
spore_print_color_black = size, #k
spore_print_color_brown = size, #n 
spore_print_color_buff = size, #b
spore_print_color_chocolate = size, #h
spore_print_color_green = size, #r
spore_print_color_orange = size, #o
spore_print_color_purple = size, #u
spore_print_color_white = size, #w
spore_print_color_yellow = size, #y 

#population (21)
population_abundant = size, #a
population_clustered = size, #c
population_numerous = size, #n
population_scattered = size, #s
population_several = size, #v
population_solitary = size, #y

#habitat (22)
habitat_grasses = size, #g
habitat_leaves = size, #l
habitat_meadows = size, #m
habitat_paths = size, #p
habitat_urban = size, #u
habitat_waste = size, #w
habitat_woods = size) #d

df_mushrooms
# Out:
# 8124×126 DataFrame. Omitted printing of 122 columns
# │ Row  │ class   │ cap_shape_bell │ cap_shape_conical │ cap_shape_convex │
# │      │ Float64 │ Float64        │ Float64           │ Float64          │
# ├──────┼─────────┼────────────────┼───────────────────┼──────────────────┤
# │ 1    │ NaN     │ NaN            │ NaN               │ NaN              │
# │ 2    │ NaN     │ NaN            │ NaN               │ NaN              │
# │ 3    │ NaN     │ NaN            │ NaN               │ NaN              │
# │ 4    │ NaN     │ NaN            │ NaN               │ NaN              │
# │ 5    │ NaN     │ NaN            │ NaN               │ NaN              │
# │ 6    │ NaN     │ NaN            │ NaN               │ NaN              │
# │ 7    │ NaN     │ NaN            │ NaN               │ NaN              │
# │ 8    │ NaN     │ NaN            │ NaN               │ NaN              │
# │ 9    │ NaN     │ NaN            │ NaN               │ NaN              │
# ...

# %%
#for each mushroom I need to determine if it has each of the attributes 

# df = DataFrame(col1 = [], col2 = []) or construct by column df.A = 
#creating an empy dataset 


#going through each row of data 
for (i, mushroom) in enumerate(eachrow(df))
    if mushroom[:class] == "p"
        df_mushrooms.class[i] = 1 
    else
        df_mushrooms.class[i] = 0
    end 
end 

df_mushrooms
# Out:
# ArgumentError: column name :class not found in the data frame
#
# Stacktrace:
#  [1] getindex(::DataFrame, ::typeof(!), ::Symbol) at C:\Users\Owner\.julia\packages\DataFrames\yH0f6\src\other\index.jl:238
#  [2] getproperty(::DataFrame, ::Symbol) at C:\Users\Owner\.julia\packages\DataFrames\yH0f6\src\abstractdataframe\abstractdataframe.jl:219
#  [3] top-level scope at .\In[8]:0

# %%
#Lets see how these mushrooms are spreadout

markers = Dict("p" => "X", "e" => "o")

figure()
xlabel("population")
ylabel("cap_color")

for df_m in groupby(df, :class)
    outcome = df_m[1, :class]
    scatter(df_m[:, :population], df_m[:, :cap_color], label="$outcome", 
                marker=markers[outcome])
    
end
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000021A8BA58>

# %%
n_mushrooms = nrow(df)

X = zeros(n_mushrooms, 22)
fill!(X, NaN)
y = zeros(n_mushrooms)
fill!(y, NaN)

for (i, mushrooms) in enumerate(eachrow(df))
    X[i, 1] = mushrooms[:cap_shape]
    X[i, 2] = mushrooms[:cap_surface]
    X[i, 3] = mushrooms[:cap_color]
    X[i, 4] = mushrooms[:bruises]
    X[i, 5] = mushrooms[:odor]
    X[i, 6] = mushrooms[:gill_attachment]
    X[i, 7] = mushrooms[:gill_spacing]
    X[i, 8] = mushrooms[:gill_size]
    X[i, 9] = mushrooms[:gill_color]
    X[i, 10] = mushrooms[:stalk_shape]
    X[i, 11] = mushrooms[:stalk_root]
    X[i, 12] = mushrooms[:stalk_surface_above_ring]
    X[i, 13] = mushrooms[:stalk_surface_below_ring]
    X[i, 14] = mushrooms[:stalk_color_above_ring]
    X[i, 15] = mushrooms[:stalk_color_below_ring]
    X[i, 16] = mushrooms[:veil_type]
    X[i, 17] = mushrooms[:veil_color]
    X[i, 18] = mushrooms[:ring_number]
    X[i, 19] = mushrooms[:ring_type]
    X[i, 20] = mushrooms[:spore_print_color]
    X[i, 21] = mushrooms[:population]
    X[i, 22] = mushrooms[:habitat]
  
    y[i] = mushrooms[:class]
end
X
# Out:
# MethodError: Cannot `convert` an object of type String to an object of type Float64
# Closest candidates are:
#   convert(::Type{T<:Number}, !Matched::T<:Number) where T<:Number at number.jl:6
#   convert(::Type{T<:Number}, !Matched::Number) where T<:Number at number.jl:7
#   convert(::Type{T<:Number}, !Matched::Base.TwicePrecision) where T<:Number at twiceprecision.jl:250
#   ...
#
# Stacktrace:
#  [1] setindex!(::Array{Float64,2}, ::String, ::Int64, ::Int64) at .\array.jl:768
#  [2] top-level scope at .\In[7]:9
